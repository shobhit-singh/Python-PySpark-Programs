# %% [markdown]
# ### pandas 03
#
# In this notebook we will cover how we can convert Python dictionary to dataframe.
#
# |S.No|Action|Command|Input|Output|
# |:----|:-----|:-----:|:-----:|:-----:|
# |1|Convert a Python Dict to Pandas Dataframe|pd.DataFrame(dict)|dict|pandas.core.frame.DataFrame (lets call this df)|
# |2|Set the no of columns for print/head dataframe |pd.set_option('display.max_columns',n)|no of columns |None|
# |3|Set the no of rows for print/head dataframe|pd.set_option('display.max_rows',n)|no of rows |None|
# |4|Selecting the single column from dataframe|dataframe['name']/dataframe.name|column-name|pandas.core.series.Series Series is like 1-D array.  Series also have index.|
# |5|Selecting the multiple column from dataframe|dataframe[[name1,name2...]]/dataframe.name|column-name list|pandas.core.frame.DataFrame|

# %%
import pandas as pd
print("Let's start exploring", '\U0001F43C' , 'using',"\U0001F40D")
# Out:
# Let's start exploring 🐼 using 🐍

# %%
import json
import requests

url = 'https://api.github.com/users/shobhit-singh/repos'
req = requests.get(url)
text = req.text

# create a dict using the json data
parsed_dict = json.loads(text)

# 1. Converting dict to pandas dataframe
df_git_repos = pd.DataFrame(parsed_dict)

# %%
df_git_repos.head(2)
# Out:
#           id                           node_id               name  \
# 0  286203985  MDEwOlJlcG9zaXRvcnkyODYyMDM5ODU=  BigDataEnthusiast
# 1   76673904  MDEwOlJlcG9zaXRvcnk3NjY3MzkwNA==      LeafletShinyR
#
#                          full_name  private  \
# 0  shobhit-singh/BigDataEnthusiast    False
# 1      shobhit-singh/LeafletShinyR    False
#
#                                                owner  \
# 0  {'login': 'shobhit-singh', 'id': 24198148, 'no...
# 1  {'login': 'shobhit-singh', 'id': 24198148, 'no...
#
#                                             html_url  \
# 0  https://github.com/shobhit-singh/BigDataEnthus...
# 1     https://github.com/shobhit-singh/LeafletShinyR
#
#                     description   fork  \
# 0                       My Blog   True
# 1  Basic R Shiny App of Leaflet  False
#
#                                                  url  ... forks_count  \
# 0  https://api.github.com/repos/shobhit-singh/Big...  ...           0
# ...

# %%
df_git_repos.shape
# Out:
# (9, 73)

# %% [markdown]
# 9 rows & 73 columns. If you noticed above the output of df_git_repos.head(2) - it's not prining all the columns in jupyter notebook. Lets change the setting to print all the columns.

# %%
# 2. Set the no of columns for print/head dataframe
pd.set_option('display.max_columns',73)

# %%
# here you can see all the 73 columns
df_git_repos.head(2)
# Out:
#           id                           node_id               name  \
# 0  286203985  MDEwOlJlcG9zaXRvcnkyODYyMDM5ODU=  BigDataEnthusiast
# 1   76673904  MDEwOlJlcG9zaXRvcnk3NjY3MzkwNA==      LeafletShinyR
#
#                          full_name  private  \
# 0  shobhit-singh/BigDataEnthusiast    False
# 1      shobhit-singh/LeafletShinyR    False
#
#                                                owner  \
# 0  {'login': 'shobhit-singh', 'id': 24198148, 'no...
# 1  {'login': 'shobhit-singh', 'id': 24198148, 'no...
#
#                                             html_url  \
# 0  https://github.com/shobhit-singh/BigDataEnthus...
# 1     https://github.com/shobhit-singh/LeafletShinyR
#
#                     description   fork  \
# 0                       My Blog   True
# 1  Basic R Shiny App of Leaflet  False
#
#                                                  url  \
# 0  https://api.github.com/repos/shobhit-singh/Big...
# 1  https://api.github.com/repos/shobhit-singh/Lea...
#
# ...

# %%
# 4. Selecting the single column another way: df_git_repos['name']
df_git_repos.name
# Out:
# 0          BigDataEnthusiast
# 1              LeafletShinyR
# 2        my-personal-website
# 3             PLSQL-Programs
# 4    Python-Learning-Journey
# 5            Python-Programs
# 6              shobhit-singh
# 7                  StockData
# 8     Twittter-Data-Analysis
# Name: name, dtype: object

# %%
type(df_git_repos.name)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Series is like 1-D array.  Series also have index.

# %%
# 5. Selecting the multiple column from dataframe
df_git_repos[['name','description','url']]
# Out:
#                       name                                        description  \
# 0        BigDataEnthusiast                                            My Blog
# 1            LeafletShinyR                       Basic R Shiny App of Leaflet
# 2      my-personal-website          Personal website created using Bootstrap.
# 3           PLSQL-Programs                             Random PL/SQL Programs
# 4  Python-Learning-Journey                         My Python Learning Journey
# 5          Python-Programs                               Some Python Programs
# 6            shobhit-singh                                               None
# 7                StockData                  Shiny R App - Stock Data Analysis
# 8   Twittter-Data-Analysis  M.Tech (Software Engineering) Sep 2016 - Final...
#
#                                                  url
# 0  https://api.github.com/repos/shobhit-singh/Big...
# 1  https://api.github.com/repos/shobhit-singh/Lea...
# ...
